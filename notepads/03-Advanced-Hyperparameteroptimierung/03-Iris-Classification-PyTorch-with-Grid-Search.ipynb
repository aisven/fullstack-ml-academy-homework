# %% [markdown]
# ## Iris Classification with PyTorch
#
# About this example:
#
# * 4 features
# * 1 target
# * 3 target classes
# * NN
# * softmax
#
# Showcased in this example:
#
# * Simple Grid Search for Hyperparameter Optimization regarding
# * Number of Neurons in Hidden Layer
# * Dropout Rate

# %%
# in this code block we gather all imports

# PyTorch
import torch
import torch.nn as nn

# Data Splitting and Normalization is still often done using sklearn
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
#from sklearn.preprocessing import MinMaxScaler

# numpy is just used in the beginning
import numpy as np

# for some plots and the scatter matrix
from matplotlib import pyplot as plt
from matplotlib import colormaps as cm

# pandas for reading the CSV and for use with the library ppscore
import pandas as pd
#from pandas.api.types import CategoricalDtype

# ppscore for exploratory data analysis
#import ppscore as pps

# more statistics for exploratory data analysis
from scipy import stats

# %%
# in this code block we determine the device to use depending on GPU availability

device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
print('This Computation is running on {}.'.format(device))
# Out:
# This Computation is running on cpu.

# %% [markdown]
# #### Load Dataset

# %%
# in this code block we read the iris binary CSV file and perform some basic preprocessing

# read the CSV file
# using separator character semicolon
dataset_known_pd = pd.read_csv("../../data/iris.csv", sep=',', skipinitialspace=True)

# make column names pythonic
# so that they can be used in code where applicable
#dataset_known_pd.columns = dataset_known_pd.columns.str.replace(" ", "_")

dataset_known_pd.drop('Id', axis=1, inplace=True)

dataset_known_pd.rename({'SepalLengthCm': 'sepal_length',
'SepalWidthCm': 'sepal_width',
'PetalLengthCm': 'petal_length',
'PetalWidthCm': 'petal_width',
'Species': 'species'}, axis=1, inplace=True)

dataset_known_pd['species'] = dataset_known_pd['species'].map({'Iris-setosa': 0, 'Iris-versicolor': 1, 'Iris-virginica': 2})

# on a side note we choose to sort the data frame by the first column 
dataset_known_pd.sort_values(by='species', ascending=True, axis=0, inplace=True)

dataset_known_np = dataset_known_pd.to_numpy()

# number of instances often referred to as just n
n_samples = dataset_known_np.shape[0]
print(f"n_samples={n_samples}")

# number of target variables
n_targets = 1
print(f"n_targets={n_targets}")

# number of target classes
n_target_classes = 3
print(f"n_target_classes={n_target_classes}")

# number of features
n_features = dataset_known_np.shape[1] - n_targets
print(f"n_features={n_features}")

assert dataset_known_pd.shape == (n_samples, n_features + n_targets)
assert dataset_known_np.shape == (n_samples, n_features + n_targets)

X_pd = dataset_known_pd.copy().drop('species', axis=1)
X_np = X_pd.to_numpy()
assert X_np.shape == (n_samples,n_features)

y_pd = dataset_known_pd['species'].copy()
y_np = y_pd.to_numpy()
assert y_np.shape == (n_samples,)

# we normalize all sample data which improves training efficiency quite a bit
# however with this particular iris binary dataset it would also work without normalization
scaler = StandardScaler()
X_norm_np = scaler.fit_transform(X_np)

X = torch.from_numpy(X_norm_np)
y = torch.from_numpy(y_np)

# we need the target data to be of data type long for the loss function to work
if y.dtype != torch.int64:
    y = y.long()
assert X.dtype == torch.float64
assert y.dtype == torch.int64

# also create a tensor that contains the 4 features and the target
y_unsqueezed = y.unsqueeze(1)
X_y = torch.cat((X, y_unsqueezed), 1)
assert X_y.shape == (n_samples, n_features + n_targets)
assert X_y.dtype == torch.float64
# Out:
# n_samples=150
# n_targets=1
# n_target_classes=3
# n_features=4

# %%
dataset_known_pd
# Out:
#      sepal_length  sepal_width  petal_length  petal_width  species
# 0             5.1          3.5           1.4          0.2        0
# 27            5.2          3.5           1.5          0.2        0
# 28            5.2          3.4           1.4          0.2        0
# 29            4.7          3.2           1.6          0.2        0
# 30            4.8          3.1           1.6          0.2        0
# ..            ...          ...           ...          ...      ...
# 119           6.0          2.2           5.0          1.5        2
# 120           6.9          3.2           5.7          2.3        2
# 121           5.6          2.8           4.9          2.0        2
# 111           6.4          2.7           5.3          1.9        2
# 149           5.9          3.0           5.1          1.8        2
#
# [150 rows x 5 columns]

# %%
# in this code block we split the dataset randomly into data for training, validation, test

# we first attempted to do this purely in PyTorch which is still a bit difficult
#dataset_known = torch.from_numpy(dataset_known_np)
#dataset_known_subsets = torch.utils.data.random_split(dataset_known, [int(n_samples * 0.7), int(n_samples * 0.3)])
#dataset_known_train_subset = dataset_known_subsets[0]
#dataset_known_test_subset = dataset_known_subsets[1]
#assert len(dataset_known_train_subset) == 105
#assert len(dataset_known_test_subset) == 45

# however many people still use pandas and sklearn which we follow for now
X_tmp, X_test, y_tmp, y_test = train_test_split(X, y, test_size=0.20, random_state=77)

X_train, X_val, y_train, y_val = train_test_split(X_tmp, y_tmp, test_size=0.20, random_state=77)

del X_tmp
del y_tmp

assert X_train.shape[0] + X_val.shape[0] + X_test.shape[0] == n_samples
assert y_train.shape[0] + y_val.shape[0] + y_test.shape[0] == n_samples

assert X_train.ndim == 2
assert X_train.shape[1] == n_features
assert X_train.dtype == torch.float64

assert X_val.ndim == 2
assert X_val.shape[1] == n_features
assert X_val.dtype == torch.float64

assert X_test.ndim == 2
assert X_test.shape[1] == n_features
assert X_test.dtype == torch.float64

assert (n_targets == 1 and y_train.ndim == 1) or (n_targets > 1 and y_train.ndim == 2)
assert y_train.dtype == torch.int64

assert (n_targets == 1 and y_val.ndim == 1) or (n_targets > 1 and y_val.ndim == 2)
assert y_val.dtype == torch.int64

assert (n_targets == 1 and y_test.ndim == 1) or (n_targets > 1 and y_test.ndim == 2)
assert y_test.dtype == torch.int64

# %%
# in this code block we define a model

class IrisClassificationNNModel(nn.Module):
    def __init__(self,input_layer_size,hidden_layer_1_in_size,hidden_layer_1_out_size,output_layer_size,dropout_rate):
        super(IrisClassificationNNModel,self).__init__()
        self.input_layer     = nn.Linear(input_layer_size,hidden_layer_1_in_size,dtype=torch.float64)
        self.hidden_layer_1  = nn.Linear(hidden_layer_1_in_size,hidden_layer_1_out_size,dtype=torch.float64)
        self.output_layer    = nn.Linear(hidden_layer_1_out_size,output_layer_size,dtype=torch.float64)
        self.relu = nn.ReLU()
        self.dropout_1 = nn.Dropout(dropout_rate)
        self.dropout_2 = nn.Dropout(dropout_rate)
    
    def forward(self, X):
        o = self.relu(self.input_layer(X))
        o = self.dropout_1(o)
        o = self.relu(self.hidden_layer_1(o))
        o = self.dropout_2(o)
        o = self.output_layer(o)
        return o

# %%
# in this code block we define a our function to get from the raw model output to classes

# note that alternatively we could decide to put some or all of this into layers in the model

def logits_to_probabilities_to_classes(y_logits):
    #print(f"y_logits.shape={y_logits.shape}")
    #print(f"y_logits[0]={y_logits[0]}")
    assert y_logits.dtype == torch.float64

    # obtain probabilities that add up to 1.0 using softmax
    y_pred_probs = torch.softmax(y_logits, dim=1)
    #print(f"y_pred_probs.shape={y_pred_probs.shape}")
    #print(f"y_pred_probs[0]={y_pred_probs[0]}")
    #print(f"y_pred_probs[0].sum()={y_pred_probs[0].sum()}")
    assert y_pred_probs.dtype == torch.float64
    assert y_pred_probs.shape == y_logits.shape

    # obtain the vector of class values using argmax
    y_pred_classes = y_pred_probs.argmax(dim=1)
    #print(f"y_pred_classes.shape={y_pred_classes.shape}")
    #print(f"y_pred_classes[0]={y_pred_classes[0]}")
    assert y_pred_classes.dtype == torch.int64
    assert y_pred_classes.ndim == 1

    return  y_pred_classes

# %%
# in this code block we define a function for measuring prediction accuracy

def classification_accuracy(y_pred_classes_reference, y_pred_classes):
    assert y_pred_classes_reference.shape == y_pred_classes.shape
    # the following tensor will contain True for true positives and False for true negatives
    comparison = y_pred_classes_reference == y_pred_classes
    # the following tensor will contain 1.0 for true positives and 0.0 for true negatives
    comparison_float = comparison.float()
     # the mean of that tensor will thus represent the percentage of true positives, e.g. 97.5
    comparison_mean = comparison_float.mean()
    # we scale and round it to obtain the value in percent
    comparison_percent = torch.round(comparison_mean, decimals=2) * 100
    #print(f"comparison={comparison}")
    #print(f"comparison_float={comparison_float}")
    #print(f"comparison_mean={comparison_mean}")
    #print(f"comparison_percent={comparison_percent}")
    assert 0.00 <= comparison_percent and comparison_percent <= 100.00
    return comparison_percent

# %%
# in this code block we define the training process

def train_classification_model(n_epochs,
                model, loss, optimizer,
                X_train,y_train,ls_train,accs_train,
                X_val,y_val,ls_val,accs_val,
                ls_val_desired,acc_val_desired,debug):
    print("Training starts.")
    print(f"n_epochs={n_epochs}")

    # loop through the epochs one after the other
    for epoch in range(n_epochs):
        # training within the epoch
        model.train()

        optimizer.zero_grad()
        
        y_pred_logits_train = model(X_train)
        y_pred_probs_train = torch.softmax(y_pred_logits_train, dim=1)
        y_pred_classes_train = y_pred_probs_train.argmax(dim=1)
        #print(f"y_pred_logits_train.requires_grad={y_pred_logits_train.requires_grad}") # True
        #print(f"y_pred_probs_train.requires_grad={y_pred_probs_train.requires_grad}") # True
        #print(f"y_pred_classes_train.requires_grad={y_pred_classes_train.requires_grad}") # False
        
        # compute and record training loss in this epoch
        l_train = loss(y_pred_logits_train, y_train)
        ls_train[epoch] = l_train.item()

        l_train.backward()

        optimizer.step()

        # compute and record training accuracy in this epoch
        accs_train[epoch] = classification_accuracy(y_pred_classes_train, y_train).item()

        # validation within the epoch
        model.eval()
        with torch.inference_mode():
            y_pred_logits_val = model(X_val)
            y_pred_classes_val = logits_to_probabilities_to_classes(y_pred_logits_val)

            # compute and record validation loss in this epoch
            l_val = loss(y_pred_logits_val, y_val)
            ls_val[epoch] = l_val.item()

            # compute and record validation accuracy in this epoch
            accs_val[epoch] = classification_accuracy(y_pred_classes_val, y_val).item()

        if debug and ((epoch <= 500 and epoch % 20 == 0) or (epoch > 500 and epoch % 500 == 0)):
            print(f"epoch                {epoch}")
            print(f"ls_train[epoch]      {ls_train[epoch]}")
            print(f"accs_train[epoch]    {accs_train[epoch]}")
            print(f"ls_val[epoch]        {ls_val[epoch]}")
            print(f"accs_val[epoch]      {accs_val[epoch]}")
            print(f"----------------------------------------------------------------")

        if ls_val[epoch] <= ls_val_desired and accs_val[epoch] >= acc_val_desired:
            print(f"Training ends after epoch {epoch}."
                  f"\nModel reached validation loss {ls_val[epoch]}"
                  f" which is <= desired loss of {ls_val_desired}"
                  f"\nand it reached validation accuracy of {accs_val[epoch]}%"
                  f" which is >= desired accuracy of {acc_val_desired}%.")
            break;

    if epoch == n_epochs - 1:
        print(f"Training ends after epoch {epoch}."
              "Reached last requested epoch.")

    return epoch

# %% [markdown]
# #### Insights
#
# * this model can be trained 10 times faster with Adam then SGD
# * however SGD also works
# * if max desired loss is 0.03 and min desired accuracy is 98% the model solves the test 100%

# %%
# in this code block we perform an exemplary training of the model

# max number of epochs
n_epochs_example_1 = 5000

# max desired validation loss
ls_val_desired_example_1 = 0.03

# min desired validation accuracy in percent
acc_val_desired_example_1 = 98

# learning rate
lr_example_1 = 0.007

# dropout rate
dr_example_1 = 0.2

# print debug output
debug_example_1 = True


# create model, loss, optimizer
model_example_1 = IrisClassificationNNModel(n_features, 16, 6, n_target_classes, dr_example_1).to(device)
loss_function_example_1 = nn.CrossEntropyLoss()
#optimizer = torch.optim.SGD(model.parameters(), lr=lr)
optimizer_example_1 = torch.optim.Adam(model_example_1.parameters(), lr=lr_example_1)

# note that we already put the model to the device before and now we put the data to the device
X_train.to(device)
X_val.to(device)
X_test.to(device)
y_train.to(device)
y_val.to(device)
y_test.to(device)

ls_train_example_1 = torch.zeros(n_epochs_example_1, dtype=torch.float64)
ls_train_example_1 = ls_train_example_1.to(device)
accs_train_example_1  = torch.zeros(n_epochs_example_1, dtype=torch.float64)
accs_train_example_1.to(device)

ls_val_example_1  = torch.zeros(n_epochs_example_1, dtype=torch.float64)
ls_val_example_1 = ls_val_example_1.to(device)
accs_val_example_1  = torch.zeros(n_epochs_example_1, dtype=torch.float64)
accs_val_example_1.to(device)

last_epoch_example_1 = train_classification_model(n_epochs_example_1,
                         model_example_1, loss_function_example_1, optimizer_example_1,
                         X_train, y_train, ls_train_example_1, accs_train_example_1,
                         X_val, y_val, ls_val_example_1, accs_val_example_1,
                         ls_val_desired_example_1, acc_val_desired_example_1, debug_example_1)
# Out:
# Training starts.
# n_epochs=5000
# epoch                0
# ls_train[epoch]      1.0055233221366824
# accs_train[epoch]    55.0
# ls_val[epoch]        0.9914930410971627
# accs_val[epoch]      58.0
# ----------------------------------------------------------------
# epoch                20
# ls_train[epoch]      0.6073951942832662
# accs_train[epoch]    72.0
# ls_val[epoch]        0.548110879040616
# accs_val[epoch]      79.0
# ----------------------------------------------------------------
# epoch                40
# ls_train[epoch]      0.45083024265917243
# accs_train[epoch]    78.0
# ls_val[epoch]        0.40577578347626214
# accs_val[epoch]      92.0
# ----------------------------------------------------------------
# epoch                60
# ls_train[epoch]      0.411410959494579
# accs_train[epoch]    82.0
# ls_val[epoch]        0.31394712342484393
# accs_val[epoch]      96.0
# ----------------------------------------------------------------
# epoch                80
# ls_train[epoch]      0.3130096672015058
# accs_train[epoch]    96.0
# ls_val[epoch]        0.237302135322309
# accs_val[epoch]      100.0
# ----------------------------------------------------------------
# epoch                100
# ls_train[epoch]      0.25875414960068627
# accs_train[epoch]    94.0
# ls_val[epoch]        0.19128701126877154
# accs_val[epoch]      100.0
# ----------------------------------------------------------------
# epoch                120
# ls_train[epoch]      0.2254006554178362
# accs_train[epoch]    95.0
# ls_val[epoch]        0.15522136203614198
# accs_val[epoch]      100.0
# ----------------------------------------------------------------
# epoch                140
# ls_train[epoch]      0.22520066504471792
# accs_train[epoch]    95.0
# ls_val[epoch]        0.12913628306373998
# accs_val[epoch]      100.0
# ----------------------------------------------------------------
# epoch                160
# ls_train[epoch]      0.26107884601407344
# accs_train[epoch]    92.0
# ls_val[epoch]        0.1167898851373958
# accs_val[epoch]      100.0
# ----------------------------------------------------------------
# epoch                180
# ls_train[epoch]      0.17760703263334235
# accs_train[epoch]    93.0
# ls_val[epoch]        0.10468002360662337
# accs_val[epoch]      100.0
# ----------------------------------------------------------------
# epoch                200
# ls_train[epoch]      0.20562390144160536
# accs_train[epoch]    95.0
# ls_val[epoch]        0.09210199151234856
# accs_val[epoch]      100.0
# ----------------------------------------------------------------
# epoch                220
# ls_train[epoch]      0.20279446152881078
# accs_train[epoch]    94.0
# ls_val[epoch]        0.08671498102432627
# accs_val[epoch]      100.0
# ----------------------------------------------------------------
# epoch                240
# ls_train[epoch]      0.18142248378913384
# accs_train[epoch]    95.0
# ls_val[epoch]        0.08007380935360196
# accs_val[epoch]      100.0
# ----------------------------------------------------------------
# epoch                260
# ls_train[epoch]      0.14426062208963367
# accs_train[epoch]    98.0
# ls_val[epoch]        0.07041982109368612
# accs_val[epoch]      100.0
# ----------------------------------------------------------------
# epoch                280
# ls_train[epoch]      0.18689457913931026
# accs_train[epoch]    95.0
# ls_val[epoch]        0.06967201139589481
# accs_val[epoch]      100.0
# ----------------------------------------------------------------
# epoch                300
# ls_train[epoch]      0.08882677041502858
# accs_train[epoch]    98.0
# ls_val[epoch]        0.07039712167855217
# accs_val[epoch]      100.0
# ----------------------------------------------------------------
# epoch                320
# ls_train[epoch]      0.13505797190949723
# accs_train[epoch]    96.0
# ls_val[epoch]        0.06249297050553995
# accs_val[epoch]      100.0
# ----------------------------------------------------------------
# epoch                340
# ls_train[epoch]      0.08650079950902324
# accs_train[epoch]    97.0
# ls_val[epoch]        0.053900401917558106
# accs_val[epoch]      100.0
# ----------------------------------------------------------------
# epoch                360
# ls_train[epoch]      0.16555126457004335
# accs_train[epoch]    94.0
# ls_val[epoch]        0.05584210916243056
# accs_val[epoch]      100.0
# ----------------------------------------------------------------
# epoch                380
# ls_train[epoch]      0.18406518663086927
# accs_train[epoch]    94.0
# ls_val[epoch]        0.047228197896509866
# accs_val[epoch]      100.0
# ----------------------------------------------------------------
# epoch                400
# ls_train[epoch]      0.22202231090858418
# accs_train[epoch]    93.0
# ls_val[epoch]        0.05224746147571791
# accs_val[epoch]      100.0
# ----------------------------------------------------------------
# epoch                420
# ls_train[epoch]      0.09096397502121162
# accs_train[epoch]    98.0
# ls_val[epoch]        0.045192602206516386
# accs_val[epoch]      100.0
# ----------------------------------------------------------------
# epoch                440
# ls_train[epoch]      0.1596266179888226
# accs_train[epoch]    94.0
# ls_val[epoch]        0.04098207354150592
# accs_val[epoch]      100.0
# ----------------------------------------------------------------
# epoch                460
# ls_train[epoch]      0.169182793322484
# accs_train[epoch]    94.0
# ls_val[epoch]        0.04035887240535413
# accs_val[epoch]      100.0
# ----------------------------------------------------------------
# epoch                480
# ls_train[epoch]      0.1326113196166656
# accs_train[epoch]    95.0
# ls_val[epoch]        0.04708692014481037
# accs_val[epoch]      100.0
# ----------------------------------------------------------------
# epoch                500
# ls_train[epoch]      0.2734925071797167
# accs_train[epoch]    89.0
# ls_val[epoch]        0.03957193106812616
# accs_val[epoch]      100.0
# ----------------------------------------------------------------
# Training ends after epoch 812.
# Model reached validation loss 0.029950579196302108 which is <= desired loss of 0.03
# and it reached validation accuracy of 100.0% which is >= desired accuracy of 98%.

# %%
# in this code block we visualize the training loss

plt.figure(figsize=(12,12),dpi=100)
plt.plot(ls_train_example_1[0:last_epoch_example_1], label='training loss', color='#ffb380')
plt.legend()
plt.show()

# %%
# in this code block we visualize the test loss

plt.figure(figsize=(12,12),dpi=100)
plt.plot(ls_val_example_1[0:last_epoch_example_1], label='validation loss', color='#b380ee')
plt.legend()
plt.show()

# %%
# in this code block we visualize the accuracy with respect to trainings data

plt.figure(figsize=(12,12),dpi=100)
plt.plot(accs_train_example_1[0:last_epoch_example_1], label='accuracy with respect to training data', color='#8080ff')
plt.legend()
plt.show()

# %%
# in this code block we visualize the accuracy with respect to test data

plt.figure(figsize=(12,12),dpi=100)
plt.plot(accs_val_example_1[0:last_epoch_example_1], label='accuracy with respect to validation data', color='#7750ee')
plt.legend()
plt.show()

# %%
# in this code block we define a function to test a model

def test_classification_model(model, loss, X_test, y_test, debug):
    model.eval()
    with torch.inference_mode():
        y_pred_logits_test = model(X_test)

        y_test.detach()

        l_test = loss(y_pred_logits_test, y_test)

        y_pred_classes_test = logits_to_probabilities_to_classes(y_pred_logits_test)

        y_pred_classes_test.detach()

        acc_test = classification_accuracy(y_pred_classes_test, y_test).item()

        # for each test instance compare actual vs. predicted class
        if debug:
            print(f"y_test={y_test}")
            print(f"y_pred_classes_test={y_pred_classes_test}")
        assert y_test.dtype == torch.int64
        assert y_pred_classes_test.dtype == torch.int64
        assert y_test.shape == y_pred_classes_test.shape

        if debug:
            print(y_test.eq(y_pred_classes_test))

        # the following naturally fails if accuracy is not 100% with respect to test data
        # and if at the same time this is not by chance a special unrealistic lucky shot
        #assert (y_test == y_pred_classes_test).all()

        return (l_test, acc_test)

# %%
# in this code block we run the test once on our trained example model

(l_test_example_1, acc_test_example_1) = test_classification_model(model_example_1, loss_function_example_1, X_test, y_test, True)

print(f"l_test_example_1={l_test_example_1}")
print(f"acc_test_example_1={acc_test_example_1}")
# Out:
# y_test=tensor([1, 2, 2, 1, 0, 2, 2, 2, 0, 1, 0, 2, 0, 0, 0, 2, 2, 2, 0, 1, 0, 2, 2, 1,
#         1, 1, 2, 0, 1, 2])
# y_pred_classes_test=tensor([1, 2, 2, 1, 0, 2, 2, 2, 0, 1, 0, 2, 0, 0, 0, 2, 2, 2, 0, 1, 0, 2, 2, 1,
#         1, 1, 2, 0, 1, 2])
# tensor([True, True, True, True, True, True, True, True, True, True, True, True,
#         True, True, True, True, True, True, True, True, True, True, True, True,
#         True, True, True, True, True, True])
# l_test_example_1=0.022930644178056212
# acc_test_example_1=100.0

# %%
# in this code block we define grid search to optimize hyperparameters

def perform_grid_search():
    hidden_layer_1_in_sizes_gs = torch.arange(4, 18, 2, dtype=torch.int64)
    hidden_layer_1_out_sizes_gs = torch.arange(2, 10, 2, dtype=torch.int64)
    dropout_rates_gs = torch.arange(0.0, 0.6, 0.1, dtype=torch.float64)

    # max number of epochs
    n_epochs_gs = 5000

    # max desired validation loss
    ls_val_max_desired_gs = 0.03

    # min desired validation accuracy in percent
    acc_val_min_desired_gs = 98

    # learning rate
    lr_gs = 0.007

    # print debug output
    debug_gs = False

    # tensor to store grid search results
    results_gs = torch.zeros(6, dtype=torch.float64).unsqueeze(1).T

    # perform grid search
    for current_hidden_layer_1_in_size in hidden_layer_1_in_sizes_gs:
        for current_hidden_layer_1_out_size in hidden_layer_1_out_sizes_gs:
            for current_dr in dropout_rates_gs:
                # create model, loss, optimizer
                current_model = IrisClassificationNNModel(n_features, current_hidden_layer_1_in_size, current_hidden_layer_1_out_size, n_target_classes, current_dr).to(device)
                current_loss_function = nn.CrossEntropyLoss()
                current_optimizer = torch.optim.Adam(current_model.parameters(), lr=lr_gs)

                # train model
                current_ls_train = torch.zeros(n_epochs_gs, dtype=torch.float64)
                current_ls_train = ls_train_example_1.to(device)
                current_accs_train  = torch.zeros(n_epochs_gs, dtype=torch.float64)
                current_accs_train.to(device)

                current_ls_val  = torch.zeros(n_epochs_gs, dtype=torch.float64)
                current_ls_val = ls_val_example_1.to(device)
                current_accs_val  = torch.zeros(n_epochs_gs, dtype=torch.float64)
                current_accs_val.to(device)

                current_last_epoch = train_classification_model(n_epochs_gs,
                                        current_model, current_loss_function, current_optimizer,
                                        X_train, y_train, current_ls_train, current_accs_train,
                                        X_val, y_val, current_ls_val, current_accs_val,
                                        ls_val_max_desired_gs, acc_val_min_desired_gs, debug_gs)

                # test model
                (current_l_test, current_acc_test) = test_classification_model(current_model, current_loss_function, X_test, y_test, debug_gs)

                current_results = torch.round(torch.tensor([current_hidden_layer_1_in_size, current_hidden_layer_1_out_size, current_dr, current_last_epoch, current_l_test, current_acc_test], dtype=torch.float64), decimals=2).unsqueeze(1).T

                results_gs = torch.cat((results_gs, current_results), dim=0)

    return results_gs

# %%
# in this code block we run the grid search

results_gs = perform_grid_search()
# Out:
# Training starts.
# n_epochs=5000
# Training ends after epoch 2503.
# Model reached validation loss 0.02874869093959624 which is <= desired loss of 0.03
# and it reached validation accuracy of 100.0% which is >= desired accuracy of 98%.
# Training starts.
# n_epochs=5000
# Training ends after epoch 4999.Reached last requested epoch.
# Training starts.
# n_epochs=5000
# Training ends after epoch 4999.Reached last requested epoch.
# Training starts.
# n_epochs=5000
# Training ends after epoch 4999.Reached last requested epoch.
# Training starts.
# n_epochs=5000
# Training ends after epoch 4999.Reached last requested epoch.
# Training starts.
# n_epochs=5000
# Training ends after epoch 4999.Reached last requested epoch.
# Training starts.
# n_epochs=5000
# Training ends after epoch 643.
# Model reached validation loss 0.029807518565754827 which is <= desired loss of 0.03
# and it reached validation accuracy of 100.0% which is >= desired accuracy of 98%.
# Training starts.
# n_epochs=5000
# Training ends after epoch 621.
# Model reached validation loss 0.029746293598904183 which is <= desired loss of 0.03
# and it reached validation accuracy of 100.0% which is >= desired accuracy of 98%.
# Training starts.
# n_epochs=5000
# Training ends after epoch 4999.Reached last requested epoch.
# Training starts.
# n_epochs=5000
# Training ends after epoch 4999.Reached last requested epoch.
# Training starts.
# n_epochs=5000
# Training ends after epoch 4999.Reached last requested epoch.
# Training starts.
# n_epochs=5000
# Training ends after epoch 4999.Reached last requested epoch.
# Training starts.
# n_epochs=5000
# Training ends after epoch 233.
# Model reached validation loss 0.029690701718310824 which is <= desired loss of 0.03
# and it reached validation accuracy of 100.0% which is >= desired accuracy of 98%.
# Training starts.
# n_epochs=5000
# Training ends after epoch 492.
# Model reached validation loss 0.029784639932348814 which is <= desired loss of 0.03
# and it reached validation accuracy of 100.0% which is >= desired accuracy of 98%.
# Training starts.
# n_epochs=5000
# Training ends after epoch 4999.Reached last requested epoch.
# Training starts.
# n_epochs=5000
# Training ends after epoch 4999.Reached last requested epoch.
# Training starts.
# n_epochs=5000
# Training ends after epoch 4999.Reached last requested epoch.
# Training starts.
# n_epochs=5000
# Training ends after epoch 4999.Reached last requested epoch.
# Training starts.
# n_epochs=5000
# Training ends after epoch 108.
# Model reached validation loss 0.029861544779873243 which is <= desired loss of 0.03
# and it reached validation accuracy of 100.0% which is >= desired accuracy of 98%.
# Training starts.
# n_epochs=5000
# Training ends after epoch 426.
# Model reached validation loss 0.029493347790925415 which is <= desired loss of 0.03
# and it reached validation accuracy of 100.0% which is >= desired accuracy of 98%.
# Training starts.
# n_epochs=5000
# Training ends after epoch 4999.Reached last requested epoch.
# Training starts.
# n_epochs=5000
# Training ends after epoch 4999.Reached last requested epoch.
# Training starts.
# n_epochs=5000
# Training ends after epoch 4999.Reached last requested epoch.
# Training starts.
# n_epochs=5000
# Training ends after epoch 4999.Reached last requested epoch.
# Training starts.
# n_epochs=5000
# Training ends after epoch 264.
# Model reached validation loss 0.029907745268234046 which is <= desired loss of 0.03
# and it reached validation accuracy of 100.0% which is >= desired accuracy of 98%.
# Training starts.
# n_epochs=5000
# Training ends after epoch 2015.
# Model reached validation loss 0.029799268616593117 which is <= desired loss of 0.03
# and it reached validation accuracy of 100.0% which is >= desired accuracy of 98%.
# Training starts.
# n_epochs=5000
# Training ends after epoch 4999.Reached last requested epoch.
# Training starts.
# n_epochs=5000
# Training ends after epoch 4999.Reached last requested epoch.
# Training starts.
# n_epochs=5000
# Training ends after epoch 4999.Reached last requested epoch.
# Training starts.
# n_epochs=5000
# Training ends after epoch 4999.Reached last requested epoch.
# Training starts.
# n_epochs=5000
# Training ends after epoch 149.
# Model reached validation loss 0.029620111252057768 which is <= desired loss of 0.03
# and it reached validation accuracy of 100.0% which is >= desired accuracy of 98%.
# Training starts.
# n_epochs=5000
# Training ends after epoch 269.
# Model reached validation loss 0.029229321615482095 which is <= desired loss of 0.03
# and it reached validation accuracy of 100.0% which is >= desired accuracy of 98%.
# Training starts.
# n_epochs=5000
# Training ends after epoch 638.
# Model reached validation loss 0.02993584477263855 which is <= desired loss of 0.03
# and it reached validation accuracy of 100.0% which is >= desired accuracy of 98%.
# Training starts.
# n_epochs=5000
# Training ends after epoch 4999.Reached last requested epoch.
# Training starts.
# n_epochs=5000
# Training ends after epoch 4999.Reached last requested epoch.
# Training starts.
# n_epochs=5000
# Training ends after epoch 4999.Reached last requested epoch.
# Training starts.
# n_epochs=5000
# Training ends after epoch 116.
# Model reached validation loss 0.029695890844880654 which is <= desired loss of 0.03
# and it reached validation accuracy of 100.0% which is >= desired accuracy of 98%.
# Training starts.
# n_epochs=5000
# Training ends after epoch 340.
# Model reached validation loss 0.029431379427898367 which is <= desired loss of 0.03
# and it reached validation accuracy of 100.0% which is >= desired accuracy of 98%.
# Training starts.
# n_epochs=5000
# Training ends after epoch 2590.
# Model reached validation loss 0.029894330693087282 which is <= desired loss of 0.03
# and it reached validation accuracy of 100.0% which is >= desired accuracy of 98%.
# Training starts.
# n_epochs=5000
# Training ends after epoch 2710.
# Model reached validation loss 0.029744422548482818 which is <= desired loss of 0.03
# and it reached validation accuracy of 100.0% which is >= desired accuracy of 98%.
# Training starts.
# n_epochs=5000
# Training ends after epoch 1216.
# Model reached validation loss 0.029912303537422736 which is <= desired loss of 0.03
# and it reached validation accuracy of 100.0% which is >= desired accuracy of 98%.
# Training starts.
# n_epochs=5000
# Training ends after epoch 4999.Reached last requested epoch.
# Training starts.
# n_epochs=5000
# Training ends after epoch 138.
# Model reached validation loss 0.029676414515952296 which is <= desired loss of 0.03
# and it reached validation accuracy of 100.0% which is >= desired accuracy of 98%.
# Training starts.
# n_epochs=5000
# Training ends after epoch 214.
# Model reached validation loss 0.029649955060970633 which is <= desired loss of 0.03
# and it reached validation accuracy of 100.0% which is >= desired accuracy of 98%.
# Training starts.
# n_epochs=5000
# Training ends after epoch 4999.Reached last requested epoch.
# Training starts.
# n_epochs=5000
# Training ends after epoch 421.
# Model reached validation loss 0.029973488667233567 which is <= desired loss of 0.03
# and it reached validation accuracy of 100.0% which is >= desired accuracy of 98%.
# Training starts.
# n_epochs=5000
# Training ends after epoch 4999.Reached last requested epoch.
# Training starts.
# n_epochs=5000
# Training ends after epoch 4999.Reached last requested epoch.
# Training starts.
# n_epochs=5000
# Training ends after epoch 1359.
# Model reached validation loss 0.029947140333108496 which is <= desired loss of 0.03
# and it reached validation accuracy of 100.0% which is >= desired accuracy of 98%.
# Training starts.
# n_epochs=5000
# Training ends after epoch 4999.Reached last requested epoch.
# Training starts.
# n_epochs=5000
# Training ends after epoch 4999.Reached last requested epoch.
# Training starts.
# n_epochs=5000
# Training ends after epoch 4999.Reached last requested epoch.
# Training starts.
# n_epochs=5000
# Training ends after epoch 4999.Reached last requested epoch.
# Training starts.
# n_epochs=5000
# Training ends after epoch 4999.Reached last requested epoch.
# Training starts.
# n_epochs=5000
# Training ends after epoch 141.
# Model reached validation loss 0.0297268117315368 which is <= desired loss of 0.03
# and it reached validation accuracy of 100.0% which is >= desired accuracy of 98%.
# Training starts.
# n_epochs=5000
# Training ends after epoch 557.
# Model reached validation loss 0.029887635690647656 which is <= desired loss of 0.03
# and it reached validation accuracy of 100.0% which is >= desired accuracy of 98%.
# Training starts.
# n_epochs=5000
# Training ends after epoch 4999.Reached last requested epoch.
# Training starts.
# n_epochs=5000
# Training ends after epoch 2691.
# Model reached validation loss 0.02991623671255932 which is <= desired loss of 0.03
# and it reached validation accuracy of 100.0% which is >= desired accuracy of 98%.
# Training starts.
# n_epochs=5000
# Training ends after epoch 4999.Reached last requested epoch.
# Training starts.
# n_epochs=5000
# Training ends after epoch 4999.Reached last requested epoch.
# Training starts.
# n_epochs=5000
# Training ends after epoch 121.
# Model reached validation loss 0.029782875537077633 which is <= desired loss of 0.03
# and it reached validation accuracy of 100.0% which is >= desired accuracy of 98%.
# Training starts.
# n_epochs=5000
# Training ends after epoch 204.
# Model reached validation loss 0.0292516286275346 which is <= desired loss of 0.03
# and it reached validation accuracy of 100.0% which is >= desired accuracy of 98%.
# Training starts.
# n_epochs=5000
# Training ends after epoch 1585.
# Model reached validation loss 0.02989093802916082 which is <= desired loss of 0.03
# and it reached validation accuracy of 100.0% which is >= desired accuracy of 98%.
# Training starts.
# n_epochs=5000
# Training ends after epoch 531.
# Model reached validation loss 0.02985639619642265 which is <= desired loss of 0.03
# and it reached validation accuracy of 100.0% which is >= desired accuracy of 98%.
# Training starts.
# n_epochs=5000
# Training ends after epoch 4999.Reached last requested epoch.
# Training starts.
# n_epochs=5000
# Training ends after epoch 4999.Reached last requested epoch.
# Training starts.
# n_epochs=5000
# Training ends after epoch 170.
# Model reached validation loss 0.02994345933687875 which is <= desired loss of 0.03
# and it reached validation accuracy of 100.0% which is >= desired accuracy of 98%.
# Training starts.
# n_epochs=5000
# Training ends after epoch 195.
# Model reached validation loss 0.029724713711478248 which is <= desired loss of 0.03
# and it reached validation accuracy of 100.0% which is >= desired accuracy of 98%.
# Training starts.
# n_epochs=5000
# Training ends after epoch 237.
# Model reached validation loss 0.028884667221561248 which is <= desired loss of 0.03
# and it reached validation accuracy of 100.0% which is >= desired accuracy of 98%.
# Training starts.
# n_epochs=5000
# Training ends after epoch 367.
# Model reached validation loss 0.029203050882008058 which is <= desired loss of 0.03
# and it reached validation accuracy of 100.0% which is >= desired accuracy of 98%.
# Training starts.
# n_epochs=5000
# Training ends after epoch 653.
# Model reached validation loss 0.02951973809777761 which is <= desired loss of 0.03
# and it reached validation accuracy of 100.0% which is >= desired accuracy of 98%.
# Training starts.
# n_epochs=5000
# Training ends after epoch 4999.Reached last requested epoch.
# Training starts.
# n_epochs=5000
# Training ends after epoch 1411.
# Model reached validation loss 0.029992627188466403 which is <= desired loss of 0.03
# and it reached validation accuracy of 100.0% which is >= desired accuracy of 98%.
# Training starts.
# n_epochs=5000
# Training ends after epoch 4999.Reached last requested epoch.
# Training starts.
# n_epochs=5000
# Training ends after epoch 4999.Reached last requested epoch.
# Training starts.
# n_epochs=5000
# Training ends after epoch 4999.Reached last requested epoch.
# Training starts.
# n_epochs=5000
# Training ends after epoch 4999.Reached last requested epoch.
# Training starts.
# n_epochs=5000
# Training ends after epoch 4999.Reached last requested epoch.
# Training starts.
# n_epochs=5000
# Training ends after epoch 412.
# Model reached validation loss 0.029985658896256887 which is <= desired loss of 0.03
# and it reached validation accuracy of 100.0% which is >= desired accuracy of 98%.
# Training starts.
# n_epochs=5000
# Training ends after epoch 835.
# Model reached validation loss 0.029345130836042635 which is <= desired loss of 0.03
# and it reached validation accuracy of 100.0% which is >= desired accuracy of 98%.
# Training starts.
# n_epochs=5000
# Training ends after epoch 2163.
# Model reached validation loss 0.029961058310539093 which is <= desired loss of 0.03
# and it reached validation accuracy of 100.0% which is >= desired accuracy of 98%.
# Training starts.
# n_epochs=5000
# Training ends after epoch 495.
# Model reached validation loss 0.02978833115768142 which is <= desired loss of 0.03
# and it reached validation accuracy of 100.0% which is >= desired accuracy of 98%.
# Training starts.
# n_epochs=5000
# Training ends after epoch 4999.Reached last requested epoch.
# Training starts.
# n_epochs=5000
# Training ends after epoch 4999.Reached last requested epoch.
# Training starts.
# n_epochs=5000
# Training ends after epoch 104.
# Model reached validation loss 0.029429253700351047 which is <= desired loss of 0.03
# and it reached validation accuracy of 100.0% which is >= desired accuracy of 98%.
# Training starts.
# n_epochs=5000
# Training ends after epoch 142.
# Model reached validation loss 0.028759966008385155 which is <= desired loss of 0.03
# and it reached validation accuracy of 100.0% which is >= desired accuracy of 98%.
# Training starts.
# n_epochs=5000
# Training ends after epoch 186.
# Model reached validation loss 0.02890104486682687 which is <= desired loss of 0.03
# and it reached validation accuracy of 100.0% which is >= desired accuracy of 98%.
# Training starts.
# n_epochs=5000
# Training ends after epoch 457.
# Model reached validation loss 0.029711289535861083 which is <= desired loss of 0.03
# and it reached validation accuracy of 100.0% which is >= desired accuracy of 98%.
# Training starts.
# n_epochs=5000
# Training ends after epoch 1537.
# Model reached validation loss 0.029958371552778917 which is <= desired loss of 0.03
# and it reached validation accuracy of 100.0% which is >= desired accuracy of 98%.
# Training starts.
# n_epochs=5000
# Training ends after epoch 4999.Reached last requested epoch.
# Training starts.
# n_epochs=5000
# Training ends after epoch 127.
# Model reached validation loss 0.029904298347491722 which is <= desired loss of 0.03
# and it reached validation accuracy of 100.0% which is >= desired accuracy of 98%.
# Training starts.
# n_epochs=5000
# Training ends after epoch 162.
# Model reached validation loss 0.029832410075449362 which is <= desired loss of 0.03
# and it reached validation accuracy of 100.0% which is >= desired accuracy of 98%.
# Training starts.
# n_epochs=5000
# Training ends after epoch 378.
# Model reached validation loss 0.02980697826808822 which is <= desired loss of 0.03
# and it reached validation accuracy of 100.0% which is >= desired accuracy of 98%.
# Training starts.
# n_epochs=5000
# Training ends after epoch 4999.Reached last requested epoch.
# Training starts.
# n_epochs=5000
# Training ends after epoch 922.
# Model reached validation loss 0.029968240418860367 which is <= desired loss of 0.03
# and it reached validation accuracy of 100.0% which is >= desired accuracy of 98%.
# Training starts.
# n_epochs=5000
# Training ends after epoch 4999.Reached last requested epoch.
# Training starts.
# n_epochs=5000
# Training ends after epoch 1664.
# Model reached validation loss 0.02935904609272576 which is <= desired loss of 0.03
# and it reached validation accuracy of 100.0% which is >= desired accuracy of 98%.
# Training starts.
# n_epochs=5000
# Training ends after epoch 4999.Reached last requested epoch.
# Training starts.
# n_epochs=5000
# Training ends after epoch 4999.Reached last requested epoch.
# Training starts.
# n_epochs=5000
# Training ends after epoch 4999.Reached last requested epoch.
# Training starts.
# n_epochs=5000
# Training ends after epoch 4999.Reached last requested epoch.
# Training starts.
# n_epochs=5000
# Training ends after epoch 4999.Reached last requested epoch.
# Training starts.
# n_epochs=5000
# Training ends after epoch 355.
# Model reached validation loss 0.029893771047298113 which is <= desired loss of 0.03
# and it reached validation accuracy of 100.0% which is >= desired accuracy of 98%.
# Training starts.
# n_epochs=5000
# Training ends after epoch 560.
# Model reached validation loss 0.029971886376288157 which is <= desired loss of 0.03
# and it reached validation accuracy of 100.0% which is >= desired accuracy of 98%.
# Training starts.
# n_epochs=5000
# Training ends after epoch 203.
# Model reached validation loss 0.029846779830773527 which is <= desired loss of 0.03
# and it reached validation accuracy of 100.0% which is >= desired accuracy of 98%.
# Training starts.
# n_epochs=5000
# Training ends after epoch 753.
# Model reached validation loss 0.029369954296698655 which is <= desired loss of 0.03
# and it reached validation accuracy of 100.0% which is >= desired accuracy of 98%.
# Training starts.
# n_epochs=5000
# Training ends after epoch 4999.Reached last requested epoch.
# Training starts.
# n_epochs=5000
# Training ends after epoch 4999.Reached last requested epoch.
# Training starts.
# n_epochs=5000
# Training ends after epoch 106.
# Model reached validation loss 0.02987271553306173 which is <= desired loss of 0.03
# and it reached validation accuracy of 100.0% which is >= desired accuracy of 98%.
# Training starts.
# n_epochs=5000
# Training ends after epoch 115.
# Model reached validation loss 0.029955687362398037 which is <= desired loss of 0.03
# and it reached validation accuracy of 100.0% which is >= desired accuracy of 98%.
# Training starts.
# n_epochs=5000
# Training ends after epoch 275.
# Model reached validation loss 0.02932559274312814 which is <= desired loss of 0.03
# and it reached validation accuracy of 100.0% which is >= desired accuracy of 98%.
# Training starts.
# n_epochs=5000
# Training ends after epoch 586.
# Model reached validation loss 0.02960909409398704 which is <= desired loss of 0.03
# and it reached validation accuracy of 100.0% which is >= desired accuracy of 98%.
# Training starts.
# n_epochs=5000
# Training ends after epoch 496.
# Model reached validation loss 0.02979668233506416 which is <= desired loss of 0.03
# and it reached validation accuracy of 100.0% which is >= desired accuracy of 98%.
# Training starts.
# n_epochs=5000
# Training ends after epoch 4999.Reached last requested epoch.
# Training starts.
# n_epochs=5000
# Training ends after epoch 81.
# Model reached validation loss 0.02926232201458719 which is <= desired loss of 0.03
# and it reached validation accuracy of 100.0% which is >= desired accuracy of 98%.
# Training starts.
# n_epochs=5000
# Training ends after epoch 181.
# Model reached validation loss 0.029834908035474016 which is <= desired loss of 0.03
# and it reached validation accuracy of 100.0% which is >= desired accuracy of 98%.
# Training starts.
# n_epochs=5000
# Training ends after epoch 206.
# Model reached validation loss 0.028743346320907873 which is <= desired loss of 0.03
# and it reached validation accuracy of 100.0% which is >= desired accuracy of 98%.
# Training starts.
# n_epochs=5000
# Training ends after epoch 208.
# Model reached validation loss 0.02976982055465491 which is <= desired loss of 0.03
# and it reached validation accuracy of 100.0% which is >= desired accuracy of 98%.
# Training starts.
# n_epochs=5000
# Training ends after epoch 1441.
# Model reached validation loss 0.029441958664277817 which is <= desired loss of 0.03
# and it reached validation accuracy of 100.0% which is >= desired accuracy of 98%.
# Training starts.
# n_epochs=5000
# Training ends after epoch 4999.Reached last requested epoch.
# Training starts.
# n_epochs=5000
# Training ends after epoch 1112.
# Model reached validation loss 0.02997575311032755 which is <= desired loss of 0.03
# and it reached validation accuracy of 100.0% which is >= desired accuracy of 98%.
# Training starts.
# n_epochs=5000
# Training ends after epoch 4369.
# Model reached validation loss 0.029813485765743997 which is <= desired loss of 0.03
# and it reached validation accuracy of 100.0% which is >= desired accuracy of 98%.
# Training starts.
# n_epochs=5000
# Training ends after epoch 4999.Reached last requested epoch.
# Training starts.
# n_epochs=5000
# Training ends after epoch 4999.Reached last requested epoch.
# Training starts.
# n_epochs=5000
# Training ends after epoch 4999.Reached last requested epoch.
# Training starts.
# n_epochs=5000
# Training ends after epoch 4999.Reached last requested epoch.
# Training starts.
# n_epochs=5000
# Training ends after epoch 117.
# Model reached validation loss 0.02969872828517477 which is <= desired loss of 0.03
# and it reached validation accuracy of 100.0% which is >= desired accuracy of 98%.
# Training starts.
# n_epochs=5000
# Training ends after epoch 174.
# Model reached validation loss 0.02989612781696371 which is <= desired loss of 0.03
# and it reached validation accuracy of 100.0% which is >= desired accuracy of 98%.
# Training starts.
# n_epochs=5000
# Training ends after epoch 379.
# Model reached validation loss 0.027316734170988292 which is <= desired loss of 0.03
# and it reached validation accuracy of 100.0% which is >= desired accuracy of 98%.
# Training starts.
# n_epochs=5000
# Training ends after epoch 563.
# Model reached validation loss 0.0299598526083938 which is <= desired loss of 0.03
# and it reached validation accuracy of 100.0% which is >= desired accuracy of 98%.
# Training starts.
# n_epochs=5000
# Training ends after epoch 4999.Reached last requested epoch.
# Training starts.
# n_epochs=5000
# Training ends after epoch 4999.Reached last requested epoch.
# Training starts.
# n_epochs=5000
# Training ends after epoch 135.
# Model reached validation loss 0.028988734572042377 which is <= desired loss of 0.03
# and it reached validation accuracy of 100.0% which is >= desired accuracy of 98%.
# Training starts.
# n_epochs=5000
# Training ends after epoch 169.
# Model reached validation loss 0.02884059527410832 which is <= desired loss of 0.03
# and it reached validation accuracy of 100.0% which is >= desired accuracy of 98%.
# Training starts.
# n_epochs=5000
# Training ends after epoch 628.
# Model reached validation loss 0.029920232967902975 which is <= desired loss of 0.03
# and it reached validation accuracy of 100.0% which is >= desired accuracy of 98%.
# Training starts.
# n_epochs=5000
# Training ends after epoch 300.
# Model reached validation loss 0.02994266303387164 which is <= desired loss of 0.03
# and it reached validation accuracy of 100.0% which is >= desired accuracy of 98%.
# Training starts.
# n_epochs=5000
# Training ends after epoch 570.
# Model reached validation loss 0.02964118968894738 which is <= desired loss of 0.03
# and it reached validation accuracy of 100.0% which is >= desired accuracy of 98%.
# Training starts.
# n_epochs=5000
# Training ends after epoch 1340.
# Model reached validation loss 0.029992876678037152 which is <= desired loss of 0.03
# and it reached validation accuracy of 100.0% which is >= desired accuracy of 98%.
# Training starts.
# n_epochs=5000
# Training ends after epoch 89.
# Model reached validation loss 0.028910101399948016 which is <= desired loss of 0.03
# and it reached validation accuracy of 100.0% which is >= desired accuracy of 98%.
# Training starts.
# n_epochs=5000
# Training ends after epoch 168.
# Model reached validation loss 0.029231249303163342 which is <= desired loss of 0.03
# and it reached validation accuracy of 100.0% which is >= desired accuracy of 98%.
# Training starts.
# n_epochs=5000
# Training ends after epoch 205.
# Model reached validation loss 0.029375652069341538 which is <= desired loss of 0.03
# and it reached validation accuracy of 100.0% which is >= desired accuracy of 98%.
# Training starts.
# n_epochs=5000
# Training ends after epoch 537.
# Model reached validation loss 0.02967467424664685 which is <= desired loss of 0.03
# and it reached validation accuracy of 100.0% which is >= desired accuracy of 98%.
# Training starts.
# n_epochs=5000
# Training ends after epoch 390.
# Model reached validation loss 0.029761462528235194 which is <= desired loss of 0.03
# and it reached validation accuracy of 100.0% which is >= desired accuracy of 98%.
# Training starts.
# n_epochs=5000
# Training ends after epoch 2054.
# Model reached validation loss 0.02986399827362667 which is <= desired loss of 0.03
# and it reached validation accuracy of 100.0% which is >= desired accuracy of 98%.
# Training starts.
# n_epochs=5000
# Training ends after epoch 4999.Reached last requested epoch.
# Training starts.
# n_epochs=5000
# Training ends after epoch 4999.Reached last requested epoch.
# Training starts.
# n_epochs=5000
# Training ends after epoch 4999.Reached last requested epoch.
# Training starts.
# n_epochs=5000
# Training ends after epoch 4999.Reached last requested epoch.
# Training starts.
# n_epochs=5000
# Training ends after epoch 4999.Reached last requested epoch.
# Training starts.
# n_epochs=5000
# Training ends after epoch 4999.Reached last requested epoch.
# Training starts.
# n_epochs=5000
# Training ends after epoch 817.
# Model reached validation loss 0.029972616770108606 which is <= desired loss of 0.03
# and it reached validation accuracy of 100.0% which is >= desired accuracy of 98%.
# Training starts.
# n_epochs=5000
# Training ends after epoch 384.
# Model reached validation loss 0.029412912590214783 which is <= desired loss of 0.03
# and it reached validation accuracy of 100.0% which is >= desired accuracy of 98%.
# Training starts.
# n_epochs=5000
# Training ends after epoch 319.
# Model reached validation loss 0.0289973189411678 which is <= desired loss of 0.03
# and it reached validation accuracy of 100.0% which is >= desired accuracy of 98%.
# Training starts.
# n_epochs=5000
# Training ends after epoch 1519.
# Model reached validation loss 0.029196607248468467 which is <= desired loss of 0.03
# and it reached validation accuracy of 100.0% which is >= desired accuracy of 98%.
# Training starts.
# n_epochs=5000
# Training ends after epoch 948.
# Model reached validation loss 0.029625992334129134 which is <= desired loss of 0.03
# and it reached validation accuracy of 100.0% which is >= desired accuracy of 98%.
# Training starts.
# n_epochs=5000
# Training ends after epoch 4999.Reached last requested epoch.
# Training starts.
# n_epochs=5000
# Training ends after epoch 122.
# Model reached validation loss 0.029788068758076578 which is <= desired loss of 0.03
# and it reached validation accuracy of 100.0% which is >= desired accuracy of 98%.
# Training starts.
# n_epochs=5000
# Training ends after epoch 85.
# Model reached validation loss 0.029763491739898968 which is <= desired loss of 0.03
# and it reached validation accuracy of 100.0% which is >= desired accuracy of 98%.
# Training starts.
# n_epochs=5000
# Training ends after epoch 172.
# Model reached validation loss 0.02914288319895159 which is <= desired loss of 0.03
# and it reached validation accuracy of 100.0% which is >= desired accuracy of 98%.
# Training starts.
# n_epochs=5000
# Training ends after epoch 198.
# Model reached validation loss 0.029831448975646133 which is <= desired loss of 0.03
# and it reached validation accuracy of 100.0% which is >= desired accuracy of 98%.
# Training starts.
# n_epochs=5000
# Training ends after epoch 378.
# Model reached validation loss 0.029877193695773435 which is <= desired loss of 0.03
# and it reached validation accuracy of 100.0% which is >= desired accuracy of 98%.
# Training starts.
# n_epochs=5000
# Training ends after epoch 790.
# Model reached validation loss 0.029943105773337513 which is <= desired loss of 0.03
# and it reached validation accuracy of 100.0% which is >= desired accuracy of 98%.
# Training starts.
# n_epochs=5000
# Training ends after epoch 106.
# Model reached validation loss 0.029925293612001785 which is <= desired loss of 0.03
# and it reached validation accuracy of 100.0% which is >= desired accuracy of 98%.
# Training starts.
# n_epochs=5000
# Training ends after epoch 118.
# Model reached validation loss 0.028255857966846303 which is <= desired loss of 0.03
# and it reached validation accuracy of 100.0% which is >= desired accuracy of 98%.
# Training starts.
# n_epochs=5000
# Training ends after epoch 129.
# Model reached validation loss 0.029822221266637278 which is <= desired loss of 0.03
# and it reached validation accuracy of 100.0% which is >= desired accuracy of 98%.
# Training starts.
# n_epochs=5000
# Training ends after epoch 218.
# Model reached validation loss 0.029380435730766038 which is <= desired loss of 0.03
# and it reached validation accuracy of 100.0% which is >= desired accuracy of 98%.
# Training starts.
# n_epochs=5000
# Training ends after epoch 373.
# Model reached validation loss 0.02967964622492397 which is <= desired loss of 0.03
# and it reached validation accuracy of 100.0% which is >= desired accuracy of 98%.
# Training starts.
# n_epochs=5000
# Training ends after epoch 676.
# Model reached validation loss 0.029789996884954862 which is <= desired loss of 0.03
# and it reached validation accuracy of 100.0% which is >= desired accuracy of 98%.

# %%
# in this code block we look at the grid search results

results_gs_pd = pd.DataFrame(results_gs.numpy()).drop(0, axis=0)
results_gs_pd = results_gs_pd.set_axis(['hl_1_in_size', 'hl_1_out_size', 'dr', 'epochs', 'test_loss', 'test_acc'], axis=1, copy=False)

results_gs_pd
# Out:
#      hl_1_in_size  hl_1_out_size   dr  epochs  test_loss  test_acc
# 1             4.0            2.0  0.0  2503.0       0.11      97.0
# 2             4.0            2.0  0.1  4999.0       0.14      97.0
# 3             4.0            2.0  0.2  4999.0       0.22      97.0
# 4             4.0            2.0  0.3  4999.0       0.22      97.0
# 5             4.0            2.0  0.4  4999.0       0.19     100.0
# ..            ...            ...  ...     ...        ...       ...
# 164          16.0            8.0  0.1   118.0       0.04     100.0
# 165          16.0            8.0  0.2   129.0       0.05     100.0
# 166          16.0            8.0  0.3   218.0       0.08      97.0
# 167          16.0            8.0  0.4   373.0       0.03     100.0
# 168          16.0            8.0  0.5   676.0       0.04     100.0
#
# [168 rows x 6 columns]

# %%
# in this code block we define an EDA

def perform_grid_search_results_eda(results_gs_pd):
    # number of instances
    print(f"n={results_gs_pd.shape[0]}")

    # location parameters
    print(f"mean={results_gs_pd.mean(axis=0)}")
    print(f"trimmed_mean={stats.trim_mean(results_gs_pd.astype('float32'), proportiontocut=0.10, axis=0)}")
    print(f"mode={stats.mode(results_gs_pd, keepdims=True)}")

    # statistical dispersion measures
    def range_np(a: np.ndarray) -> np.ndarray:
        result = a.max(axis=0) - a.min(axis=0)
        return result

    print(f"range={range_np(results_gs_pd)}")
    print(f"iqr={stats.iqr(results_gs_pd, axis=0)}")

    print(f"percentile_10={np.percentile(results_gs_pd, 10.0, axis=0)}")
    print(f"percentile_25={np.percentile(results_gs_pd, 25.0, axis=0)}")
    print(f"median={np.percentile(results_gs_pd, 50.0, axis=0)}")
    print(f"percentile_75={np.percentile(results_gs_pd, 75.0, axis=0)}")
    print(f"percentile_90={np.percentile(results_gs_pd, 90.0, axis=0)}")

    def mad_np(a: np.ndarray) -> np.ndarray:
        result = np.mean(np.absolute(a - np.mean(a, axis=0)), axis=0)
        return result

    print(f"mad={mad_np(results_gs_pd)}")

    print(f"std={results_gs_pd.std(axis=0)}")
    print(f"var={results_gs_pd.var(axis=0)}")

    # association measures
    print(f"\ncorrelation_matrix=\n{np.corrcoef(results_gs_pd, rowvar=False).round(decimals=2)}")

    # we have a look at a scatter matrix
    pd.plotting.scatter_matrix(results_gs_pd, 
                            c=results_gs_pd['test_acc'], 
                            figsize=(17, 17),
                            cmap = cm['cool'],
                            diagonal = 'hist')

# %%
# in this code block we run the EDA on the grid search results

perform_grid_search_results_eda(results_gs_pd)
# Out:
# n=168
# mean=hl_1_in_size       10.000000
# hl_1_out_size       5.000000
# dr                  0.250000
# epochs           2482.488095
# test_loss           0.172798
# test_acc           95.559524
# dtype: float64
# trimmed_mean=[1.0000000e+01 5.0000000e+00 2.4999988e-01 2.4654043e+03 1.1713231e-01
#  9.7772057e+01]
# mode=ModeResult(mode=array([[4.000e+00, 2.000e+00, 0.000e+00, 4.999e+03, 4.000e-02, 1.000e+02]]), count=array([[24, 42, 28, 71, 22, 75]]))
# range=hl_1_in_size       12.00
# hl_1_out_size       6.00
# dr                  0.50
# epochs           4918.00
# test_loss           2.01
# test_acc           70.00
# dtype: float64
# iqr=[8.00000e+00 3.00000e+00 3.00000e-01 4.70525e+03 1.60000e-01 3.00000e+00]
# percentile_10=[4.000e+00 2.000e+00 0.000e+00 1.401e+02 3.000e-02 9.300e+01]
# percentile_25=[6.0000e+00 3.5000e+00 1.0000e-01 2.9375e+02 4.0000e-02 9.7000e+01]
# median=[1.000e+01 5.000e+00 2.500e-01 1.426e+03 8.500e-02 9.700e+01]
# percentile_75=[1.400e+01 6.500e+00 4.000e-01 4.999e+03 2.000e-01 1.000e+02]
# percentile_90=[1.600e+01 8.000e+00 5.000e-01 4.999e+03 3.720e-01 1.000e+02]
# mad=hl_1_in_size        3.428571
# hl_1_out_size       2.000000
# dr                  0.150000
# epochs           2156.225057
# test_loss           0.146649
# test_acc            4.976474
# dtype: float64
# std=hl_1_in_size        4.011958
# hl_1_out_size       2.242753
# dr                  0.171293
# epochs           2232.094068
# test_loss           0.254007
# test_acc           10.469060
# dtype: float64
# var=hl_1_in_size     1.609581e+01
# hl_1_out_size    5.029940e+00
# dr               2.934132e-02
# epochs           4.982244e+06
# test_loss        6.451967e-02
# test_acc         1.096012e+02
# dtype: float64
#
# correlation_matrix=
# [[ 1.    0.   -0.   -0.27  0.04 -0.01]
#  [ 0.    1.   -0.   -0.47 -0.37  0.29]
#  [-0.   -0.    1.    0.55 -0.03 -0.05]
#  [-0.27 -0.47  0.55  1.    0.33 -0.31]
#  [ 0.04 -0.37 -0.03  0.33  1.   -0.58]
#  [-0.01  0.29 -0.05 -0.31 -0.58  1.  ]]

# %%
# in this code block we filter out the good results

results_gs_good_pd = results_gs_pd[(results_gs_pd.epochs <= 500) & (results_gs_pd.test_acc >= 99.0)]

results_gs_good_pd
# Out:
#      hl_1_in_size  hl_1_out_size   dr  epochs  test_loss  test_acc
# 13            4.0            6.0  0.0   233.0       0.04     100.0
# 14            4.0            6.0  0.1   492.0       0.05     100.0
# 20            4.0            8.0  0.1   426.0       0.02     100.0
# 25            6.0            2.0  0.0   264.0       0.06     100.0
# 38            6.0            6.0  0.1   340.0       0.04     100.0
# 44            6.0            8.0  0.1   214.0       0.03     100.0
# 46            6.0            8.0  0.3   421.0       0.04     100.0
# 62            8.0            6.0  0.1   204.0       0.05     100.0
# 67            8.0            8.0  0.0   170.0       0.02     100.0
# 70            8.0            8.0  0.3   367.0       0.03     100.0
# 82           10.0            4.0  0.3   495.0       0.06     100.0
# 86           10.0            6.0  0.1   142.0       0.05     100.0
# 88           10.0            6.0  0.3   457.0       0.03     100.0
# 93           10.0            8.0  0.2   378.0       0.04     100.0
# 103          12.0            4.0  0.0   355.0       0.06     100.0
# 105          12.0            4.0  0.2   203.0       0.06     100.0
# 115          12.0            8.0  0.0    81.0       0.08     100.0
# 116          12.0            8.0  0.1   181.0       0.04     100.0
# 117          12.0            8.0  0.2   206.0       0.06     100.0
# 118          12.0            8.0  0.3   208.0       0.04     100.0
# 127          14.0            4.0  0.0   117.0       0.06     100.0
# 128          14.0            4.0  0.1   174.0       0.06     100.0
# 134          14.0            6.0  0.1   169.0       0.05     100.0
# 136          14.0            6.0  0.3   300.0       0.04     100.0
# 140          14.0            8.0  0.1   168.0       0.04     100.0
# 143          14.0            8.0  0.4   390.0       0.03     100.0
# 152          16.0            4.0  0.1   384.0       0.06     100.0
# 153          16.0            4.0  0.2   319.0       0.04     100.0
# 157          16.0            6.0  0.0   122.0       0.08     100.0
# 158          16.0            6.0  0.1    85.0       0.08     100.0
# 159          16.0            6.0  0.2   172.0       0.05     100.0
# 160          16.0            6.0  0.3   198.0       0.06     100.0
# 164          16.0            8.0  0.1   118.0       0.04     100.0
# 165          16.0            8.0  0.2   129.0       0.05     100.0
# 167          16.0            8.0  0.4   373.0       0.03     100.0

# %%
# in this code block we run the EDA on the good grid search results

perform_grid_search_results_eda(results_gs_good_pd)
# Out:
# n=35
# mean=hl_1_in_size      11.428571
# hl_1_out_size      6.342857
# dr                 0.154286
# epochs           258.714286
# test_loss          0.047714
# test_acc         100.000000
# dtype: float64
# trimmed_mean=[1.1724138e+01 6.4827585e+00 1.4827588e-01 2.5268965e+02 4.6896540e-02
#  1.0000000e+02]
# mode=ModeResult(mode=array([[1.6e+01, 8.0e+00, 1.0e-01, 8.1e+01, 4.0e-02, 1.0e+02]]), count=array([[ 9, 15, 13,  1, 10, 35]]))
# range=hl_1_in_size      12.00
# hl_1_out_size      6.00
# dr                 0.40
# epochs           414.00
# test_loss          0.06
# test_acc           0.00
# dtype: float64
# iqr=[7.000e+00 2.000e+00 1.500e-01 2.005e+02 2.000e-02 0.000e+00]
# percentile_10=[6.000e+00 4.000e+00 0.000e+00 1.196e+02 3.000e-02 1.000e+02]
# percentile_25=[8.000e+00 6.000e+00 1.000e-01 1.695e+02 4.000e-02 1.000e+02]
# median=[1.20e+01 6.00e+00 1.00e-01 2.08e+02 5.00e-02 1.00e+02]
# percentile_75=[1.5e+01 8.0e+00 2.5e-01 3.7e+02 6.0e-02 1.0e+02]
# percentile_90=[1.60e+01 8.00e+00 3.00e-01 4.24e+02 6.00e-02 1.00e+02]
# mad=hl_1_in_size       3.428571
# hl_1_out_size      1.420408
# dr                 0.102041
# epochs           107.444898
# test_loss          0.012637
# test_acc           0.000000
# dtype: float64
# std=hl_1_in_size       4.045955
# hl_1_out_size      1.714006
# dr                 0.119663
# epochs           122.539927
# test_loss          0.015546
# test_acc           0.000000
# dtype: float64
# var=hl_1_in_size        16.369748
# hl_1_out_size        2.937815
# dr                   0.014319
# epochs           15016.033613
# test_loss            0.000242
# test_acc             0.000000
# dtype: float64
#
# correlation_matrix=
# [[ 1.   -0.07  0.21 -0.42  0.38   nan]
#  [-0.07  1.    0.28 -0.08 -0.48   nan]
#  [ 0.21  0.28  1.    0.47 -0.36   nan]
#  [-0.42 -0.08  0.47  1.   -0.42   nan]
#  [ 0.38 -0.48 -0.36 -0.42  1.     nan]
#  [  nan   nan   nan   nan   nan   nan]]
# /Users/sven/gh/fullstack-ml-academy-homework/.venv/lib/python3.9/site-packages/numpy/lib/function_base.py:2854: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /Users/sven/gh/fullstack-ml-academy-homework/.venv/lib/python3.9/site-packages/numpy/lib/function_base.py:2855: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /Users/sven/gh/fullstack-ml-academy-homework/.venv/lib/python3.9/site-packages/pandas/plotting/_matplotlib/misc.py:101: UserWarning: Attempting to set identical low and high xlims makes transformation singular; automatically expanding.
#   ax.set_xlim(boundaries_list[j])
# /Users/sven/gh/fullstack-ml-academy-homework/.venv/lib/python3.9/site-packages/pandas/plotting/_matplotlib/misc.py:102: UserWarning: Attempting to set identical low and high ylims makes transformation singular; automatically expanding.
#   ax.set_ylim(boundaries_list[i])
# /Users/sven/gh/fullstack-ml-academy-homework/.venv/lib/python3.9/site-packages/pandas/plotting/_matplotlib/misc.py:92: UserWarning: Attempting to set identical low and high xlims makes transformation singular; automatically expanding.
#   ax.set_xlim(boundaries_list[i])
